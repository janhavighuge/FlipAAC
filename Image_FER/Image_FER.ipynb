# %%
import cv2
import deepface
from deepface import DeepFace
import matplotlib.pyplot as plt

# %%
img = cv2.imread('happyboy.jpg')

# %%
plt.imshow(img)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:13<00:00,  3.27s/it]

# %%
predictions[0]
# Out:
# {'emotion': {'angry': 0.0011311545441743368,
#   'disgust': 1.638782610148794e-09,
#   'fear': 0.015934160405105226,
#   'happy': 99.98263120547719,
#   'sad': 0.00030532243727940226,
#   'surprise': 1.291835910183822e-11,
#   'neutral': 1.746313614552906e-08},
#  'dominant_emotion': 'happy',
#  'region': {'x': 804, 'y': 367, 'w': 271, 'h': 271},
#  'age': 25,
#  'gender': {'Woman': 0.3152760677039623, 'Man': 99.68472123146057},
#  'dominant_gender': 'Man',
#  'race': {'asian': 99.99778866754703,
#   'indian': 0.00010935523929829739,
#   'black': 1.3969203016512695e-08,
#   'white': 0.00034134863869496654,
#   'middle eastern': 2.465437896739463e-09,
#   'latino hispanic': 0.0017650757542251128},
#  'dominant_race': 'asian'}

# %%
type(predictions)
# Out:
# list

# %%
type(predictions[0])
# Out:
# dict

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

faces = faceCascade.detectMultiScale(gray,1.1,4)


for(x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2. FONT_HERSHEY_SIMPLEX

cv2.putText(img,
               predictions[0]['dominant_emotion'],
               (50, 50),
               font, 1,
               (0, 0, 255),
                2,
                cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img1 = cv2.imread('Feared_oldman.jpeg')

# %%
plt.imshow(cv2.cvtColor(img1, cv2.COLOR_BGR2RGB))

# %%
predictions = DeepFace.analyze(img1)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.88it/s]

# %%
predictions
# Out:
# [{'emotion': {'angry': 16.399920964236316,
#    'disgust': 0.002601386741375319,
#    'fear': 78.82758252785102,
#    'happy': 0.12248986897929721,
#    'sad': 0.01955080195446622,
#    'surprise': 4.627851672640543,
#    'neutral': 1.993260253532575e-06},
#   'dominant_emotion': 'fear',
#   'region': {'x': 223, 'y': 83, 'w': 153, 'h': 153},
#   'age': 30,
#   'gender': {'Woman': 0.005036584843765013, 'Man': 99.994957447052},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.787694650154987,
#    'indian': 7.9810311186928224,
#    'black': 56.172141800650465,
#    'white': 10.121524937243755,
#    'middle eastern': 3.8576504652291814,
#    'latino hispanic': 20.07996112584836},
#   'dominant_race': 'black'}]

# %%
#predictions[0]['dominant_emotion']
predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 #predictions[0]['dominant_emotion']
# ----> 2 predictions
#
# NameError: name 'predictions' is not defined

# %%
predictions[0]['emotion']
# Out:
# {'angry': 16.399920964236316,
#  'disgust': 0.002601386741375319,
#  'fear': 78.82758252785102,
#  'happy': 0.12248986897929721,
#  'sad': 0.01955080195446622,
#  'surprise': 4.627851672640543,
#  'neutral': 1.993260253532575e-06}
